# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
import struct

# %%
# Replace 'your_file_path.mat' with the path to your .mat file
file_path = '../Data/joesdata.mat'

# Load the .mat file
DATA = loadmat(file_path)['DATA']
print(DATA.shape)
DATA = DATA.T
# Out:
# (1000000, 4)

# %%
num_rows = DATA.shape[0]

fig, axs = plt.subplots(num_rows, 1)  # Adjust figsize as needed

# Plotting each row as a subplot
for i in range(num_rows):
    axs[i].plot(DATA[i])
    #axs[i].set_title(f'Row {i+1}')

# Adjust layout
#plt.tight_layout()

# Show the plot
plt.show()

# %%
import scipy.ndimage as ndimage
from scipy import signal


def detect_pulses(audio_signal, noise_threshold=90, pulse_threshold=150, pulse_duration=100):
    # average signal
    pulse_filter = np.ones(256) / 256
    filtered_signal = np.convolve(audio_signal, pulse_filter, mode='valid')
    plt.plot(filtered_signal)
    plt.show()
    
    filtered_signal[filtered_signal < 80] = 0  
    plt.plot(filtered_signal)
    plt.show()
    
    filt = np.ones(256)
    output = np.convolve(filtered_signal,filt)
    output[output > 0] = 1
    
    diff = np.diff(output)
    output = np.where(diff != 0)[0]
    
    #print("output ",output)
    non_zero_regions = np.split(filtered_signal, output)
    #print(len(non_zero_regions))
    max_values_in_regions = [(index,np.argmax(region),np.max(region)) for index,region in enumerate(non_zero_regions) if region.any()]
    #print(max_values_in_regions)
    
    if len(non_zero_regions) > 1:
        print('Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
        print(max_values_in_regions)
    #print(filtered_signal)
    #print(new_filtered_signal)
    '''
    pulse_starts = np.where(above_noise & above_pulse_threshold)[0]
    pulse_ends = pulse_starts + pulse_duration

    pulse_intervals = []
    for start, end in zip(pulse_starts, pulse_ends):
        pulse_intervals.append((start, end))

    return pulse_intervals
    '''

# %%
ch1_data = DATA[0]
length = len(ch1_data)
samples_per_segment = 50000

num_segments = length // samples_per_segment

for i in range(200):
    print('########################################')
    samps = ch1_data[i*samples_per_segment:(i+1)*samples_per_segment]
    #samps = np.power(samps, 2, dtype=np.int64)
    samps = samps.astype('float64') **2
    #print(np.amax(samps),np.amin(samps))
    samps = np.sqrt(samps)
    #print(np.amax(samps),np.amin(samps))
    plt.plot(samps)
    plt.show()
    
    detect_pulses(samps)
# Out:
# ########################################
# ########################################
# ########################################
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 291, 282.734375), (3, 67, 91.2265625)]
# ########################################
# ########################################
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 178, 94.91015625), (3, 429, 82.97265625)]
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 197, 91.75390625), (3, 718, 142.8203125), (5, 718, 235.19140625), (7, 229, 104.3515625), (9, 428, 93.8125), (11, 684, 238.33984375), (13, 37, 88.88671875), (15, 71, 101.40625)]
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 318, 343.3203125), (3, 48, 89.0703125)]
# ########################################
# ########################################
# ########################################
# ########################################
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 339, 421.6015625), (3, 68, 89.7421875)]
# ########################################
# ########################################
# ########################################
# ########################################
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 285, 339.05859375), (3, 92, 96.3984375)]
# ########################################
# Clicks detected!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [(1, 171, 90.9453125), (3, 21, 80.484375), (5, 89, 91.640625), (7, 404, 101.92578125), (9, 685, 203.59375), (11, 691, 163.5703125), (13, 96, 86.44140625), (15, 55, 88.21484375), (17, 374, 109.41015625), (19, 425, 119.55859375), (21, 173, 87.8125), (23, 1171, 210.7265625)]
# ########################################
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#      15 plt.plot(samps)
#      16 plt.show()
# ---> 18 detect_pulses(samps)
#
# Input In [6], in detect_pulses(audio_signal, noise_threshold, pulse_threshold, pulse_duration)
#       5 def detect_pulses(audio_signal, noise_threshold=90, pulse_threshold=150, pulse_duration=100):
#       6     # average signal
#       7     pulse_filter = np.ones(256) / 256
# ----> 8     filtered_signal = np.convolve(audio_signal, pulse_filter, mode='valid')
#       9     plt.plot(filtered_signal)
#      10     plt.show()
#
# File <__array_function__ internals>:180, in convolve(*args, **kwargs)
#
# File ~/opt/miniconda3/lib/python3.9/site-packages/numpy/core/numeric.py:849, in convolve(a, v, mode)
#     847     raise ValueError('a cannot be empty')
#     848 if len(v) == 0:
# --> 849     raise ValueError('v cannot be empty')
#     850 return multiarray.correlate(a, v[::-1], mode)
#
# ValueError: v cannot be empty

# %%
np.where([4,2,3,9,5,6] == [1,5])
# Out:
# (array([], dtype=int64),)

# %%
plt.plot(samps[11000:11500])
plt.show()

# %%
values = np.ones(1)
plt.plot(filter_values)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 values = np.ones(1)
# ----> 2 plt.plot(filter_values)
#       3 plt.show()
#
# NameError: name 'filter_values' is not defined

# %%
plt.plot(pulse_filter)
plt.show()

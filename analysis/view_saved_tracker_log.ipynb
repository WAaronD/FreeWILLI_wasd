# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from tracker_log_analysis import *

# %%
#path_doa = "../listener_program/231105_090101_007440_tracker"
path_doa = "tracks_old/231105_090101_000000_tracker_164"
# !pwd
path_doa = "../listener_program/deployment_files/231105_010101_000000_tracker"
#path_doa = "../listener_program/deployment_files/231105_010101_778720_tracker"
#path_doa = "tracks/231105_090101_000000_tracker_103"
kalman_log = read_log_csv(path_doa)
print(kalman_log)
plot_log(path_doa, kalman_log, [])
# Out:
# /home/harp/Documents/Embedded_miniHarp/analysis
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 path_doa = "../listener_program/deployment_files/231105_010101_000000_tracker"
#       5 #path_doa = "../listener_program/deployment_files/231105_010101_778720_tracker"
#       6 #path_doa = "tracks/231105_090101_000000_tracker_103"
# ----> 7 kalman_log = read_log_csv(path_doa)
#       8 print(kalman_log)
#       9 plot_log(path_doa, kalman_log, [])
#
# File ~/Documents/Embedded_miniHarp/analysis/tracker_log_analysis.py:89, in read_log_csv(filename)
#      87 LogEntry = namedtuple('LogEntry', ['time', 'filter_id', 'updated_x', 'updated_y'])
#      88 kalman_log = []
# ---> 89 with open(filename, 'r') as csvfile:
#      90     reader = csv.DictReader(csvfile)
#      91     for row in reader:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../listener_program/deployment_files/231105_010101_000000_tracker'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import numpy as np
from tracker_log_analysis import *

# %%
#path_doa = "../listener_program/231105_090101_007440_tracker"
path_doa = "tracks_old/231105_090101_000000_tracker_164"
# !pwd
path_doa = "../listener_program/deployment_files/231105_010101_000000_tracker"
#path_doa = "../listener_program/deployment_files/231105_010101_778720_tracker"
#path_doa = "tracks/231105_090101_000000_tracker_103"
kalman_log = read_log_csv(path_doa)
print(kalman_log)
plot_log(path_doa, kalman_log, [])
# Out:
# /home/harp/Documents/Embedded_miniHarp/analysis
# [LogEntry(time=1699146087724480.0, filter_id=0, updated_x=160.029, updated_y=68.6724), LogEntry(time=1699146087734400.0, filter_id=0, updated_x=160.204, updated_y=66.646), LogEntry(time=1699146087784000.0, filter_id=0, updated_x=160.184, updated_y=67.4218), LogEntry(time=1699146087833600.0, filter_id=0, updated_x=160.345, updated_y=68.224), LogEntry(time=1699146087893120.0, filter_id=0, updated_x=160.353, updated_y=67.9003), LogEntry(time=1699146087952640.0, filter_id=0, updated_x=160.467, updated_y=68.5477), LogEntry(time=1699146088002240.0, filter_id=0, updated_x=160.524, updated_y=67.7605), LogEntry(time=1699146088061760.0, filter_id=0, updated_x=160.349, updated_y=68.1614), LogEntry(time=1699146088111360.0, filter_id=0, updated_x=160.28, updated_y=68.4042), LogEntry(time=1699146088170880.0, filter_id=0, updated_x=160.187, updated_y=68.6003), LogEntry(time=1699146088220480.0, filter_id=0, updated_x=160.165, updated_y=68.6772), LogEntry(time=1699146088280000.0, filter_id=0, updated_x=160.11, updated_y=68.7836), LogEntry(time=1699146088329600.0, filter_id=0, updated_x=160.106, updated_y=68.8095), LogEntry(time=1699146088389120.0, filter_id=0, updated_x=160.069, updated_y=68.8742), LogEntry(time=1699146088438720.0, filter_id=0, updated_x=160.045, updated_y=68.8994), LogEntry(time=1699146088498240.0, filter_id=0, updated_x=160.049, updated_y=68.9171), LogEntry(time=1699146088756160.0, filter_id=0, updated_x=159.827, updated_y=71.086), LogEntry(time=1699146088865280.0, filter_id=0, updated_x=159.835, updated_y=72.4933), LogEntry(time=1699146088914880.0, filter_id=0, updated_x=159.755, updated_y=73.1443), LogEntry(time=1699146088964480.0, filter_id=0, updated_x=159.891, updated_y=73.6812), LogEntry(time=1699146089073600.0, filter_id=0, updated_x=159.675, updated_y=74.1666), LogEntry(time=1699146089133120.0, filter_id=0, updated_x=159.502, updated_y=74.5548), LogEntry(time=1699146089361280.0, filter_id=0, updated_x=159.242, updated_y=75.6372), LogEntry(time=1699146089420800.0, filter_id=0, updated_x=159.307, updated_y=75.1922), LogEntry(time=1699146089480320.0, filter_id=0, updated_x=159.198, updated_y=75.3373), LogEntry(time=1699146089539840.0, filter_id=0, updated_x=159.307, updated_y=74.2162), LogEntry(time=1699146090025920.0, filter_id=0, updated_x=158.979, updated_y=75.701), LogEntry(time=1699146090085440.0, filter_id=0, updated_x=159.052, updated_y=75.2309), LogEntry(time=1699146090135040.0, filter_id=0, updated_x=158.995, updated_y=75.2699), LogEntry(time=1699146090194560.0, filter_id=0, updated_x=158.949, updated_y=75.3132), LogEntry(time=1699146090353280.0, filter_id=0, updated_x=158.866, updated_y=75.5703), LogEntry(time=1699146090402880.0, filter_id=0, updated_x=158.933, updated_y=75.2535), LogEntry(time=1699146090482240.0, filter_id=0, updated_x=158.777, updated_y=75.5361), LogEntry(time=1699146091384960.0, filter_id=0, updated_x=158.4, updated_y=77.1225), LogEntry(time=1699146091444480.0, filter_id=0, updated_x=158.658, updated_y=76.3266), LogEntry(time=1699146091484160.0, filter_id=0, updated_x=158.682, updated_y=76.1161), LogEntry(time=1699146091543680.0, filter_id=0, updated_x=158.693, updated_y=75.9887), LogEntry(time=1699146091593280.0, filter_id=0, updated_x=158.705, updated_y=75.8743), LogEntry(time=1699146091652800.0, filter_id=0, updated_x=158.821, updated_y=75.5633), LogEntry(time=1699146091722240.0, filter_id=0, updated_x=158.808, updated_y=75.5583), LogEntry(time=1699146100858560.0, filter_id=0, updated_x=158.944, updated_y=75.1353), LogEntry(time=1699146105243200.0, filter_id=0, updated_x=159.241, updated_y=74.2345), LogEntry(time=1699146105302720.0, filter_id=0, updated_x=158.995, updated_y=72.5868), LogEntry(time=1699146105372160.0, filter_id=0, updated_x=158.712, updated_y=73.2604), LogEntry(time=1699146106007040.0, filter_id=0, updated_x=158.999, updated_y=72.7092), LogEntry(time=1699146089857280.0, filter_id=0, updated_x=160.185, updated_y=67.999), LogEntry(time=1699146089926720.0, filter_id=0, updat ...
# Datetime object:  2023-11-05 01:01:01+00:00
# Unix time in microseconds:  1699146061000000
# unique tracks:  [0 1 2 3 4 5]
